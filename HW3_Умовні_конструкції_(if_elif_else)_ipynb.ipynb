# %% [markdown]
# <a href="https://colab.research.google.com/github/Bubukisapisa/ML_education/blob/main/HW3_%D0%A3%D0%BC%D0%BE%D0%B2%D0%BD%D1%96_%D0%BA%D0%BE%D0%BD%D1%81%D1%82%D1%80%D1%83%D0%BA%D1%86%D1%96%D1%97_(if_elif_else)_ipynb.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **1. Основи роботи з умовними конструкціями (if-elif-else)**
#
# Створіть змінну `cooking_time = 5` (час варіння яєць у хвилинах)
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Яйце рідке" якщо cooking_time < 4
# - "Яйце всмятку" якщо 4 <= cooking_time < 7
# - "Яйце вкруту" якщо 7 <= cooking_time < 10
# - "Яйце переварене" якщо cooking_time >= 10

# %%
cooking_time = 5

def egg_status(cook_time):
  if cook_time < 4:
    print('Яйце рідке')
  elif cook_time < 7:
    print('Яйце всмятку')
  elif cook_time < 10:
    print('Яйце всмятку')
  else:
    print('Яйце переварене')

# %%
egg_status(cooking_time)
# Out:
# Яйце всмятку

# %% [markdown]
# ---
#
# **2. Перевірка оцінки**
#
# Створіть змінну `grade = 72`
#
# Напишіть програму, яка виводить (кожен пункт оцінюється в 0.5 бала):
# - "Відмінно" якщо grade >= 90
# - "Добре" якщо 75 <= grade < 90
# - "Задовільно" якщо 60 <= grade < 75
# - "Незадовільно" якщо grade < 60

# %%
grade = 72

def grade_result(grade):
  if grade < 60:
    print('Незадовільно')
  elif grade < 75:
    print('Задовільно')
  elif grade < 90:
    print('Добре')
  else:
    print('Відмінно')

# %%
grade_result(grade)
# Out:
# Задовільно

# %% [markdown]
# ---
#
# **3. Перевірка на наявність**
#
# Створіть список продуктів в холодильнику зі значеннями ["молоко", "яйця", "масло", "сир"] і запишіть його в змінну.
#
#
# Напишіть код, який перевіряє (кожен пункт оцінюється в 0.5 бала):
# - Чи є "яйця" в списку (виведіть "Яйця є в холодильнику" або "Яєць немає")
# - Чи є "хліб" в списку

# %%
fridge = ["молоко", "яйця", "масло", "сир"]

def check_goods(fridge):
  print('Яйця є в холодильнику') if 'яйця' in fridge else print('Яєць немає')
  print('Хліб є в холодильнику') if 'хліб' in fridge else print('Хліба немає')

# %%
check_goods(fridge)
# Out:
# Яйця є в холодильнику
# Хліба немає
